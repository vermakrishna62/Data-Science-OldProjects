# %% [markdown]
# <h1>
#
#     What are Images - It is a numpy array. It is given by height, width and no. of channels
#
# </h1>

# %%
import cv2

# %%
image = cv2.imread('/home/krishna-verma/Desktop/resume-knv.png')

# %%
print(type(image))
# Out:
# <class 'numpy.ndarray'>

# %%
image.shape
# Out:
# (806, 569, 3)

# %%
"""

806 - height
569 - width
3 - channel - rgb (red, green, blue)

"""
# Out:
# '\n\n806 - height\n569 - width\n3 - channel - rgb (red, green, blue)\n\n'

# %% [markdown]
# ### Image is made by pixels.
# <ul>
#     <li>ranges from 0 to 255</li>
#     <li>binary pixel - (0,1) or (0,255)</li>
#     <li>16 bits pixel ranges from 0 to 65535</li>
# </ul>

# %%
# write image

# %%
cv2.imwrite('/home/krishna-verma/Desktop/resume-knv.png',image)
# Out:
# True

# %%
# visualize image

# %%
cv2.imshow('frame',image)
cv2.waitKey(0)
# Out:
# ...
# QObject::moveToThread: Current thread (0x1f97730) is not the object's thread (0x1d4b090).
# Cannot move to target thread (0x1f97730)
#
# QObject::moveToThread: Current thread (0x1f97730) is not the object's thread (0x1d4b090).
# Cannot move to target thread (0x1f97730)
#
# QObject::moveToThread: Current thread (0x1f97730) is not the object's thread (0x1d4b090).
# Cannot move to target thread (0x1f97730)
#
# QObject::moveToThread: Current thread (0x1f97730) is not the object's thread (0x1d4b090).
# Cannot move to target thread (0x1f97730)
#
# QObject::moveToThread: Current thread (0x1f97730) is not the object's thread (0x1d4b090).
# Cannot move to target thread (0x1f97730)
#
# QObject::moveToThread: Current thread (0x1f97730) is not the object's thread (0x1d4b090).
# Cannot move to target thread (0x1f97730)
#
# QObject::moveToThread: Current thread (0x1f97730) is not the object's thread (0x1d4b090).
# Cannot move to target thread (0x1f97730)
#
# ...
